# %%
# load data
train_data = read.csv("data/c0/class_train.csv")[,-1]
train_labels = read.csv("data/c0/class_train_labels.csv")[,-1]
test_data = read.csv("data/c0/class_test.csv")[,-1]
test_labels = read.csv("data/c0/class_test_labels.csv")[,-1]

# %%
source("R_python_script.R")

# %%
fs = 12 # number of features selected with RENT

train_data_sc = apply(train_data, 2, function(x){if(length(unique(x))>1){return(scale(x))} else{return(x)}})
#train_data_sc = scale(train_data)

################ mRMR ################
library(mRMRe)
dataset = cbind("class"=train_labels, data.frame(apply(train_data_sc,2, as.numeric)))
colnames(dataset)[1] = "class"
dataset$class = factor(dataset$class, ordered=TRUE)
dataset = mRMR.data(dataset)
result = mRMR.classic(data=dataset, target_indices = c(1), feature_count = fs)

selected_features = result@filters$`1`
selected_features = colnames(dataset@data[,selected_features])
print("Performance mRMR")
print(classification_scores(train_data[,selected_features], train_labels, test_data[,selected_features], test_labels))

############### Laplace Score #######################
library(Rdimtools)
lapl = do.lscore(as.matrix(train_data_sc), t=10, ndim = fs) # train_data must be matrix
selected_features = lapl$featidx
print("Performance L-score")
print(classification_scores(train_data[,selected_features], train_labels, test_data[,selected_features], test_labels))

############### Fisher Score ########################
fscore = do.fscore(as.matrix(train_data_sc), ndim = fs,label = train_labels)
selected_features = fscore$featidx
print("Performance F-score")
print(classification_scores(train_data[,selected_features], train_labels, test_data[,selected_features], test_labels))
# Out:
# Loading required package: survival
#
# Loading required package: igraph
#
#
# Attaching package: 'igraph'
#
#
# The following objects are masked from 'package:stats':
#
#     decompose, spectrum
#
#
# The following object is masked from 'package:base':
#
#     union
# [1] "Performance mRMR"
# $f1_1
# [1] 0.7532468
#
# $f1_0
# [1] 0.739726
#
# $acc
# [1] 0.7466667
#
# $mcc
# [1] 0.4953682
# ** ------------------------------------------------------- **
#
# ** Rdimtools
#
# **  - Dimension Reduction and Estimation Toolbox
#
# **
#
# ** Version    : 1.0.8       (2021)
#
# ** Maintainer : Kisung You  (kisungyou@outlook.com)
#
# ** Website    : https://kisungyou.com/Rdimtools/
#
# **
#
# ** Please share any bugs or suggestions to the maintainer.
#
# ** ------------------------------------------------------- **
# [1] "Performance L-score"
# $f1_1
# [1] 0.7160494
#
# $f1_0
# [1] 0.6666667
#
# $acc
# [1] 0.6933333
#
# $mcc
# [1] 0.3829644
#
# [1] "Performance F-score"
# $f1_1
# [1] 0.7466667
#
# $f1_0
# [1] 0.7466667
#
# $acc
# [1] 0.7466667
#
# $mcc
# [1] 0.5

# %%
source("stabsel_gridsearch.R")
# Out:
# Loading required package: parallel
#
# Loading required package: Matrix
#
# Loaded glmnet 4.1-2
#
# Loading required package: lattice
#
# Loading required package: ggplot2
#
#
# Attaching package: 'caret'
#
#
# The following object is masked from 'package:survival':
#
#     cluster

# %%
selected_features = stabsel_gridsearch(train_data, train_labels)
# Out:
# pfer: 0.05 cutoff: 0.6
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.05 cutoff: 0.65
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.05 cutoff: 0.7
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.05 cutoff: 0.75
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.05 cutoff: 0.8
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.05 cutoff: 0.85
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.05 cutoff: 0.9
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.1 cutoff: 0.6
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# pfer: 0.1 cutoff: 0.65
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.1 cutoff: 0.7
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.1 cutoff: 0.75
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.1 cutoff: 0.8
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.1 cutoff: 0.85
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.1 cutoff: 0.9
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.15 cutoff: 0.6
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# pfer: 0.15 cutoff: 0.65
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.15 cutoff: 0.7
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# pfer: 0.8 cutoff: 0.7
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# pfer: 0.8 cutoff: 0.75
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# pfer: 0.8 cutoff: 0.8
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# pfer: 0.8 cutoff: 0.85
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.8 cutoff: 0.9
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.85 cutoff: 0.6
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 5
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# pfer: 0.85 cutoff: 0.65
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# pfer: 0.85 cutoff: 0.7
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 5
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# pfer: 0.85 cutoff: 0.75
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# pfer: 0.85 cutoff: 0.8
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# pfer: 0.85 cutoff: 0.85
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.85 cutoff: 0.9
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.9 cutoff: 0.6
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# LENGHT SELECTED FEATURES: 5
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# pfer: 0.9 cutoff: 0.65
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 5
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# pfer: 0.9 cutoff: 0.7
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# pfer: 0.9 cutoff: 0.75
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.9 cutoff: 0.8
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# pfer: 0.9 cutoff: 0.85
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.9 cutoff: 0.9
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.95 cutoff: 0.6
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 5
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# pfer: 0.95 cutoff: 0.65
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# LENGHT SELECTED FEATURES: 3
# [1] "here"
# pfer: 0.95 cutoff: 0.7
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# pfer: 0.95 cutoff: 0.75
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 4
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# pfer: 0.95 cutoff: 0.8
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.95 cutoff: 0.85
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 1
# [1] "here"
# LENGHT SELECTED FEATURES: 0
# pfer: 0.95 cutoff: 0.9
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 0
# LENGHT SELECTED FEATURES: 2
# [1] "here"
# LENGHT SELECTED FEATURES: 0
#            0.6      0.65       0.7      0.75       0.8      0.85       0.9
# 0.05 0.3072549 0.2856471 0.2856471 0.2856471 0.3072549 0.3072549 0.3072549
# 0.1  0.4090665 0.2543319 0.2543319 0.3728097 0.3728097 0.3072549 0.3072549
# 0.15 0.2833724 0.3083797 0.3632725 0.3355010 0.2278710 0.1623156 0.3072549
# 0.2  0.3879682 0.3643812 0.4065288 0.4358116 0.3719606 0.1623156 0.2856471
# 0.25 0.4790679 0.5061953 0.3355010 0.3355010 0.2859794 0.3728097 0.3072549
# 0.3  0.4051122 0.4322396 0.4790679 0.3643812 0.2859794 0.2833724 0.2856471
# 0.35 0.4921216 0.4051122 0.4790679 0.3388109 0.3238367 0.2543319 0.3728097
# 0.4  0.4051122 0.4790679 0.4468041 0.3643812 0.2833724 0.2859794 0.3728097
# 0.45 0.4685060 0.4322396 0.4790679 0.4358116 0.2859794 0.2657283 0.2856471
# 0.5  0.4941509 0.5061953 0.4790679 0.3659093 0.3632725 0.2856471 0.2278710
# 0.55 0.4690432 0.4459994 0.4948152 0.4065288 0.3071080 0.2543319 0.3728097
# 0.6  0.4831022 0.5387072 0.5157140 0.4051122 0.3629475 0.2543319 0.2856471
# 0.65 0.4481387 0.5249569 0.4790679 0.3340843 0.3238367 0.1962235 0.1997215
# 0.7  0.4831022 0.4810912 0.4790679 0.4472997 0.3340843 0.2859794 0.3072549
# 0.75 0.4823265 0.5028989 0.4217181 0.3213089 0.3659093 0.3537354 0.2856471
# 0.8  0.5840646 0.4808582 0.4122854 0.3308172 0.4051122 0.2278710 0.3728097
# 0.85 0.5126395 0.4920203 0.4065288 0.4790679 0.3355010 0.2859794 0.3072549
# 0.9  0.4687089 0.4566899 0.4805541 0.4205554 0.3441891 0.1962235 0.1962235
# 0.95 0.4692877 0.4599630 0.5159150 0.4358116 0.3238367 0.2657283 0.4815801

# %%
classification_scores(train_data[,selected_features], train_labels, test_data[,selected_features], test_labels)
# Out:
# $f1_1
# [1] 0.7179487
#
# $f1_0
# [1] 0.6944444
#
# $acc
# [1] 0.7066667
#
# $mcc
# [1] 0.4134008
